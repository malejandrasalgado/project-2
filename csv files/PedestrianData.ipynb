# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# File name strings used to make up to name of the files
inputPath = 'C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/'
inputpartA = "COM_24PM_"
inputpartB = "-08-20"
inputpartB2 = ""
inputpartC = ".csv"
inputDay = ""
# List for data frames to hold the input from each csv as it is read
file_dfs = []

# This bit is the loop to create the name of the input file to load and then load a df by reading the CSV
for x in range(0,2):
    
    if x==0:
        inputpartB2 = "19"
    else:
        inputpartB2 = "20"
        
    for i in range(1,32):
        if i < 10:
            inputDay = "0"+str(i)
        else:
            inputDay = str(i)
        input_file = inputPath+inputpartA+inputDay+inputpartB+inputpartB2+inputpartC
        #print(input_file)

        #Append it to the master df
        try:
                print("Append ", input_file)
                csv_df = pd.read_csv (input_file,skiprows=([i for i in range(0, 8)] + [j for j in range(86, 248)]))
                csv_df["data_date"]= inputDay+inputpartB+inputpartB2
                file_dfs.append(csv_df)
        except:
                print(input_file," not found")
                continue

            
# concat all of the input files into one master dataframe
master_df = pd.concat(file_dfs)
master_df.to_csv('peds_data.csv')
# Out:
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_01-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_02-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_03-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_04-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_05-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_06-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_07-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_08-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_09-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_10-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_11-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_12-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_13-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_14-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_15-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_16-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_17-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_18-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_19-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_20-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_21-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_22-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_23-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_24-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_25-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_26-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_27-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_28-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_29-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_30-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_31-08-2019.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_01-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_02-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_03-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_04-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_05-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_06-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_07-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_08-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_09-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_10-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_11-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_12-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_13-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_14-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_15-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_16-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_17-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_18-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_19-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_20-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_21-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_22-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_23-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_24-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_25-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_26-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_27-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_28-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_29-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_30-08-2020.csv
# Append  C:/Users/aleja/OneDrive/Bootcamp/projects/Second project/csv files/COM_24PM_31-08-2020.csv
