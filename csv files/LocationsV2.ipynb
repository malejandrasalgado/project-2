# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import json

# # reading csv file 

location=  pd.read_csv('C:/Users/aleja/OneDrive/Bootcamp/projects/project-2/csv files/locationsV2.csv')
print(location)
observations=  pd.read_csv('C:/Users/aleja/OneDrive/Bootcamp/projects/project-2/csv files/peds_dataV2.csv')
observations
# Out:
#     SensorID                               Sensor   latitude   longitude
# 0          0           Bourke Street Mall (North) -37.813410  144.965225
# 1          1           Bourke Street Mall (South) -37.813723  144.965150
# 2          2                    Melbourne Central -37.810185  144.962801
# 3          3                     Town Hall (West) -37.814953  144.966194
# 4          4                       Princes Bridge -37.818819  144.967994
# ..       ...                                  ...        ...         ...
# 71        71       Bourke St - Spencer St (South) -37.816856  144.954069
# 72        72       Spring St - Flinders St (West) -37.815210  144.974777
# 73        73             Macaulay Rd - Bellair St -37.794268  144.930493
# 74        74  Harbour Esplanade - Pedestrian Path -37.814285  144.944280
# 75        75        Harbour Esplanade - Bike Path -37.814883  144.944532
#
# [76 rows x 4 columns]
# ...

# %%
newdf = pd.merge(
    location, 
    observations, 
    left_on=['Sensor'],
    right_on=['Sensor'])

# %%
newdf.reset_index()
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4712 entries, 0 to 4711
# Data columns (total 32 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SensorID    4712 non-null   int64
#  1   Sensor      4712 non-null   object
#  2   latitude    4712 non-null   float64
#  3   longitude   4712 non-null   float64
#  4   Unnamed: 0  4712 non-null   int64
#  5   Midnight    3038 non-null   float64
#  6   1am         2807 non-null   float64
#  7   2am         2751 non-null   float64
#  8   3am         2775 non-null   float64
#  9   4am         2911 non-null   float64
#  10  5am         3255 non-null   float64
#  11  6am         3428 non-null   float64
#  12  7am         3470 non-null   float64
#  13  8am         3478 non-null   float64
#  14  9am         3479 non-null   float64
#  15  10am        3479 non-null   float64
#  16  11am        3477 non-null   float64
#  17  Noon        3475 non-null   float64
# ...

# %%
def df_to_geojson(df, properties, lat='latitude', lon='longitude'):
    print (properties)
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in df.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Point',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
        
    return geojson

cols = ['Sensor','SensorID','Midnight','1am','2am','3am','4am','5am','6am','7am','8am','9am','10am','11am','Noon','1pm','2pm','3pm','4pm','5pm','6pm','7pm','8pm','9pm','10pm','11pm','dailyTotal','avgDaily','data_date']
geojson = df_to_geojson(newdf, cols)
# Out:
# ['Sensor', 'SensorID', 'Midnight', '1am', '2am', '3am', '4am', '5am', '6am', '7am', '8am', '9am', '10am', '11am', 'Noon', '1pm', '2pm', '3pm', '4pm', '5pm', '6pm', '7pm', '8pm', '9pm', '10pm', '11pm', 'dailyTotal', 'avgDaily', 'data_date']

# %%
geo_json_list = []
for i in geojson:
   #code to generate your geoJSON
   geo_json_list.append(geojson)
with open('C:/Users/aleja/OneDrive/Bootcamp/projects/project-2/csv files/data2.geojson', 'a') as f:
    json.dump(geo_json_list, f)
